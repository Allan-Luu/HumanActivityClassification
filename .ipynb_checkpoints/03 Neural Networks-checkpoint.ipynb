# %% [markdown]
# # Neural Networks

# %%
# importing basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Specific neural network models & layer types
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import Embedding, LSTM, GRU, BatchNormalization

# Ignore futurewarnings
import warnings
warnings.filterwarnings('ignore')

# %%
# reading in the data
columns = pd.read_csv('data/features2.txt', header = None)

X_train = pd.read_csv('data/Train/X_train.txt', names = columns[0], sep=' ')
X_test = pd.read_csv('data/Test/X_test.txt', names = columns[0], sep=' ')

y_train = pd.read_csv('data/Train/y_train.txt', sep=' ', header = None)
y_test = pd.read_csv('data/Test/y_test.txt', sep=' ', header = None)

# %% [markdown]
# **PLAN**
#
# For neural networks, you can simply try a fully connected NN with a few layers,
#
# first ignoring the time component and previous activity
#
# then second, you can do RNNs by feeding in say 10 time-steps and predicting the next activity

# %% [markdown]
# ### Building a Neural Network Using Keras
#
# The process of building a network using Keras can generally be broken down into four separate steps:
# 1. **Build the model**: This is the step where we will declare the structure of the network — primarily the types and sizes of the hidden layers.
# 2. **Compile the model**: This step allows us to customize some of the settings that will be used for training.
# 3. **Train the model**
# 4. **Evaluate the model and generate predictions**

# %% [markdown]
# USE SOFTMAX FOR OUTPUT LAYER BECAUSE IT ENSURES ALL PROBABILITIES ADD UP TO 1
#
# ADAM OPTIMIZER BECAUSE IT IS BEST ADAPTIVE OPTIMIZER, GOOD WITH DATASETS WITH LARGE # OF FEATURES
# https://outline.com/X7kdTG
#
# LOSS FUNCTION WILL BE SparseCategoricalCrossentropy() FOR CROSS ENTROPY BETWEEN LABELS AND PREDICTIONS
#
# METRICS WILL BE USING SparseCategoricalAccuracy() FOR MULTIVARIATE CLASSIFICATION

# %% [markdown]
# ### Fully Connected Neural Network

# %%
# Create a new sequential model
model = keras.Sequential()

# Declare the hidden layers
# We'll be using the RELU activation function for our layers for the unbound benefit
# Dense layers will be used to create a fully connected neural network model

model.add(layers.Dense(40, activation="relu"))
model.add(layers.Dense(40, activation="relu"))
model.add(layers.Dense(40, activation="relu"))
model.add(layers.Dense(40, activation="relu"))
model.add(layers.Dense(40, activation="relu"))

# Declare the output layer
# Our output layer has 12 units for the 12 different activities to be classified
# There are 6 main actions, and 6 transition actions
# Transition actions are when the participant transitions to the next position
model.add(layers.Dense(13, activation="softmax"))

# Compile the model
model.compile(
    # Optimizer
    optimizer=keras.optimizers.Adam(),  
    # Loss function to minimize
    loss=keras.losses.SparseCategoricalCrossentropy(),
    # Metric used to evaluate model
    metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

# %%
# Fit the model
history = model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer dense_16 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 243/243 [==============================] - 0s 1ms/step - loss: 0.7527 - sparse_categorical_accuracy: 0.7219
# Epoch 2/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.2580 - sparse_categorical_accuracy: 0.9016
# Epoch 3/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1969 - sparse_categorical_accuracy: 0.9267
# Epoch 4/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1509 - sparse_categorical_accuracy: 0.9379
# Epoch 5/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1307 - sparse_categorical_accuracy: 0.9466
# Epoch 6/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1309 - sparse_categorical_accuracy: 0.9446
# Epoch 7/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1069 - sparse_categorical_accuracy: 0.9548
# Epoch 8/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9628
# Epoch 9/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1093 - sparse_categorical_accuracy: 0.9553
# Epoch 10/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0941 - sparse_categorical_accuracy: 0.9624
# Epoch 11/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9616
# Epoch 12/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9650
# Epoch 13/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.1020 - sparse_categorical_accuracy: 0.9601
# Epoch 14/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9661
# Epoch 15/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0748 - sparse_categorical_accuracy: 0.9694
# Epoch 16/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0754 - sparse_categorical_accuracy: 0.9683
# Epoch 17/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0805 - sparse_categorical_accuracy: 0.9664
# Epoch 18/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9719
# Epoch 19/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9710
# Epoch 20/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9709
# Epoch 21/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0663 - sparse_categorical_accuracy: 0.9732
# Epoch 22/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0713 - sparse_categorical_accuracy: 0.9714
# Epoch 23/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9762
# Epoch 24/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9745
# Epoch 25/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9770
# Epoch 26/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0865 - sparse_categorical_accuracy: 0.9687
# Epoch 27/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9780
# Epoch 28/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9762
# Epoch 29/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0519 - sparse_categorical_accuracy: 0.9782
# Epoch 30/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9780
# Epoch 31/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0621 - sparse_categorical_accuracy: 0.9771
# Epoch 32/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9829
# Epoch 33/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9815
# Epoch 34/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0747 - sparse_categorical_accuracy: 0.9727
# Epoch 35/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9804
# Epoch 36/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9851
# Epoch 37/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9768
# Epoch 38/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9802
# Epoch 39/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0395 - sparse_categorical_accuracy: 0.9830
# Epoch 40/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9812
# Epoch 41/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0513 - sparse_categorical_accuracy: 0.9791
# Epoch 42/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0443 - sparse_categorical_accuracy: 0.9804
# Epoch 43/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9815
# Epoch 44/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0382 - sparse_categorical_accuracy: 0.9857
# Epoch 45/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9821
# Epoch 46/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9815
# Epoch 47/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9842
# Epoch 48/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9817
# Epoch 49/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9852
# Epoch 50/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0368 - sparse_categorical_accuracy: 0.9864
# Epoch 51/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9861
# Epoch 52/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9898
# Epoch 53/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0348 - sparse_categorical_accuracy: 0.9864
# Epoch 54/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9822
# Epoch 55/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0339 - sparse_categorical_accuracy: 0.9869
# Epoch 56/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0409 - sparse_categorical_accuracy: 0.9871
# Epoch 57/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9887
# Epoch 58/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0265 - sparse_categorical_accuracy: 0.9884
# Epoch 59/100
# 243/243 [==============================] - 0s 2ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9882
# Epoch 60/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9856
# Epoch 61/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0281 - sparse_categorical_accuracy: 0.9902
# Epoch 62/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0380 - sparse_categorical_accuracy: 0.9869
# Epoch 63/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0331 - sparse_categorical_accuracy: 0.9879
# Epoch 64/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9900
# Epoch 65/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0443 - sparse_categorical_accuracy: 0.9840
# Epoch 66/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0269 - sparse_categorical_accuracy: 0.9896
# Epoch 67/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0218 - sparse_categorical_accuracy: 0.9914
# Epoch 68/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0253 - sparse_categorical_accuracy: 0.9914
# Epoch 69/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9855
# Epoch 70/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0271 - sparse_categorical_accuracy: 0.9902
# Epoch 71/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9883
# Epoch 72/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9903
# Epoch 73/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9898
# Epoch 74/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9911
# Epoch 75/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0324 - sparse_categorical_accuracy: 0.9887
# Epoch 76/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9951
# Epoch 77/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9893
# Epoch 78/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0294 - sparse_categorical_accuracy: 0.9900
# Epoch 79/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9911
# Epoch 80/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9923
# Epoch 81/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0219 - sparse_categorical_accuracy: 0.9919
# Epoch 82/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0214 - sparse_categorical_accuracy: 0.9916
# Epoch 83/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0120 - sparse_categorical_accuracy: 0.9958
# Epoch 84/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0264 - sparse_categorical_accuracy: 0.9909
# Epoch 85/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0350 - sparse_categorical_accuracy: 0.9869
# Epoch 86/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9947
# Epoch 87/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9911
# Epoch 88/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9893
# Epoch 89/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0244 - sparse_categorical_accuracy: 0.9907
# Epoch 90/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9964
# Epoch 91/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0370 - sparse_categorical_accuracy: 0.9883
# Epoch 92/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9882
# Epoch 93/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9902
# Epoch 94/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0194 - sparse_categorical_accuracy: 0.9934
# Epoch 95/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9937
# Epoch 96/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0149 - sparse_categorical_accuracy: 0.9946
# Epoch 97/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0145 - sparse_categorical_accuracy: 0.9947
# Epoch 98/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9948
# Epoch 99/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0140 - sparse_categorical_accuracy: 0.9958
# Epoch 100/100
# 243/243 [==============================] - 0s 1ms/step - loss: 0.0209 - sparse_categorical_accuracy: 0.9920

# %%
# Evaluate the model using the test data and generate predictions
train_accuracy = history.history["sparse_categorical_accuracy"][-1]
result = model.evaluate(X_test, y_test, verbose=0)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {result[1]:.4f}")

predictions = model.predict(X_test)
# Out:
# Train Accuracy: 0.9920
# Test Accuracy: 0.9380

# %% [markdown]
# ### Recurrent Neural Network - LSTM

# %% [markdown]
# https://machinelearningmastery.com/sequence-classification-lstm-recurrent-neural-networks-python-keras/
